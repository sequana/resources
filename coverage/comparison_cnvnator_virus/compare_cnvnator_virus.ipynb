# %% [markdown]
# # Sequana_coverage versus CNVnator (viral genome)
#
# This notebook compares CNVnator and sequana_coverage behaviour on a viral instance (same as in the virus notebook).
#
#
# Versions used:
# - sequana 0.6.4

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = [10,7]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Here below, we provide the results of the sequana_coverage and CNVNator analysis as files within this directoty. Nevertheless, if you need to rerun the analysis yourself, you can still do it but you need to generate the BAM file for CNVnator (see virus notebook). For sequana_coverage, you could use the BED file directly, which is also use here below for the plotting. This BED file can simply be downloaded as follows.

# %%
# !wget https://github.com/sequana/resources/raw/master/coverage/JB409847.bed.bz2
# !bunzip2 JB409847.bed.bz2
# Out:
# --2018-02-03 20:08:37--  https://github.com/sequana/resources/raw/master/coverage/JB409847.bed.bz2
# Resolving github.com... 192.30.253.112, 192.30.253.113
# Connecting to github.com|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sequana/resources/master/coverage/JB409847.bed.bz2 [following]
# --2018-02-03 20:08:38--  https://raw.githubusercontent.com/sequana/resources/master/coverage/JB409847.bed.bz2
# Resolving raw.githubusercontent.com... 151.101.120.133
# Connecting to raw.githubusercontent.com|151.101.120.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63485 (62K) [application/octet-stream]
# Saving to: ‘JB409847.bed.bz2.1’
#
# JB409847.bed.bz2.1  100%[===================>]  62.00K   223KB/s    in 0.3s
#
# 2018-02-03 20:08:39 (223 KB/s) - ‘JB409847.bed.bz2.1’ saved [63485/63485]

# %% [markdown]
# # The coverage signal

# %% [markdown]
# Let us have a quick look at the coverage itself.

# %%
from sequana import GenomeCov
b = GenomeCov("JB409847.bed")
chromosome = b.chr_list[0]
chromosome.running_median(4001, circular=True)
chromosome.compute_zscore(k=2)
# you can replace the 2 previous lines by since version 0.6.4
# chromosome.run(4001, k=2, circular=True)

# %%
chromosome.plot_coverage()

# %% [markdown]
# What you see are two long deleted regions of about 700 bases (one fully deleted) and two 3-bases deleted regions on the right hand side. Our goal is to detect those 4 events automatically.

# %% [markdown]
# # Get ROIs using sequana_coverage

# %% [markdown]
# We ran the analysis with circular chromosome set on and a window parameter of
# - 1000
# - 2000
# - 3000
# - 4000
#
# For example:
# ```
# sequana_coverage -o -input JB409847.bed --no-html --no-multiqc -w 3000
# ```
#
# Results are available in 4 files for your convenience: e.g. rois_1000.csv, rois_4000.csv
#
# Note that the window size cannot be larger than a fifth of the genome length from the command line. Would you need to force it, you would need to use the library itself.

# %% [markdown]
# # Get ROIs using CNVnator

# %% [markdown]
# ```
# cnvnator -root out1.root -tree JB409847.bed
# cnvnator -root out1.root -his 1
# cnvnator -root out1.root -stat 1
# cnvnator -root out1.root -partition 1 -ngc
# cnvnator -root out1.root -call 1 -ngc > events_bin1.txt
# ```

# %% [markdown]
# The default parameter of 100 give no detection. We then use bin=10 and bin=1 and stored the results in:
#
# - events_bin1.txt
# - events_bin5.txt
# - events_bin10.txt
# - events_bin20.txt

# %% [markdown]
# # How  events are detected using CNVnator?

# %%
import pandas as pd

# %%
cnv1 = pd.read_csv("events_bin1.txt", header=None, sep='\t')
cnv5 = pd.read_csv("events_bin5.txt", header=None, sep='\t')
cnv10 = pd.read_csv("events_bin10.txt", header=None, sep='\t')
cnv20 = pd.read_csv("events_bin20.txt", header=None, sep='\t')

# %%
def plot_rois_cnv(cnv):
    chromosome.plot_coverage()
    for _, this in cnv.iterrows():
        type_ = this[0]
        positions = [int(x) for x in this[1].split(":")[1].split("-")]
        if type_ == "deletion":
            fill_between(positions, 0, 1000)
        else:
            fill_between(positions, 1000,2000)
    ylim([0,2000])    
plot_rois_cnv(cnv10)

# %% [markdown]
# Here, the two main events on the left hand side (deleted regions of several hundreds of bases) are detected. However, the short deleted regions on the right hand side (a few bases) are not.

# %% [markdown]
# # Binning of 5

# %%
plot_rois_cnv(cnv5)

# %% [markdown]
# Here again, the two main deleted regions are detected but the two short events
# are not. There is also a false detection at position 0

# %% [markdown]
# # Binning of 1

# %%
plot_rois_cnv(cnv1)

# %% [markdown]
# binning of 1 is too small: the tow deleted regions are detected but then, the small
#     deleted regions are not as such but part of larger regions

# %% [markdown]
# # How  events are detected using sequana_coverage ?

# %%
W = 2000 # can be 1000,2000,3000,4000
def plot_rois_sequana(W):
    assert W in [2000,3000,4000,1000]
    chromosome.run(W+1, circular=True)
    chromosome.plot_coverage(sample=False)
    rois = pd.read_csv("rois_{}.csv".format(W))
    for _, this in rois.iterrows():
        #if this.max_zscore >-4.5 and this.max_zscore<4.5 and this.max_cov!=0:
        #    continue    
        positions = [this.start, this.end]
            
        if this.mean_zscore > 0:
            fill_between(positions, 1000, 2000)        
        else:
            fill_between(positions, 0, 1000)
        if this.end-this.start < 100:
            axvline(this.start, ymax=0.5, lw=3, color="r")
    ylim([0,2000])

# %%
plot_rois_sequana(2000)
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="51551590-1fed-42f8-a2d4-d1185729d8f9" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="eb80f70d-726e-4ab6-be5c-62bb086d2fd0" style="padding-left: 10px;" text = ""/>

# %% [markdown]
# Using W=2000, 3000, 4000 the results are robust and consistent: the same ROIs are detected. In particular, the 2 long and 2 short deleted regions are detected;
#
# In addition, some short events no fully deleted are aslo systematically detected. The detection seems coherent visually execept maybe for the duplicated events at position 5000, which could be considered a false detection. Note, however, that the zscore associated with this events could be used to discard the events  (mean zscore of 5)

# %% [markdown]
# Now, if we decrease the W parameter to W, we may miss the large deleted regions,
# which length is 711 and 782 (to detect those events we recommend to use W as
# twice this length so about 1500)

# %%
plot_rois_sequana(1000)
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="2bd29a11-9e1c-4bef-92ab-aab6869c5725" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="1c2a2ae2-da1e-459c-8e73-5f0446717687" style="padding-left: 10px;" text = ""/>

# %% [markdown]
# So, here we still detect the two deleted regions but we see that the running
# median fits the data too closely. Consequently, we have some
# false detections at position 0, 6600, 17923 to cite a few examples.

# %% [markdown]
# # Conclusions

# %% [markdown]
# On a viral genome (length 18000), we use sequana_coverage and cnvnator to detect events of interests that can be seen by eyes on the coverage signals that is one deleted region of about 700 bases, one depleted region of about 700 and two short deleted regions of a few bases long.
#
# Sequana_coverage detects those 4 events with the default parameter (window length). It is also robust with respect to the parameter (2000,3000,4000 give the same results). Note, however, that a window of 1000 is too short and lead to possibly false detections.
#
# CNVnator detects the two long deleted events. However, the two short deleted ones are systematically missed, which is not surprising since CNVnator is designed to detect long regions. Depending of the bin parameter, some there are a few false detections. Decreasing to a bin of 1, the results are difficult to assess since most of the genome is classified as a mix of regions of interests.
#
# **computation time:**
#
# - sequana_coverage: (with --no-html and --no-multiqc options), sequana_coverage takes 2.5 seconds irrespective of the window parameter
# - cnvnator: 8.5 s for bin=5 or 10, 18s for bins=1
