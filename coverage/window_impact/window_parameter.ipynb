# %% [markdown]
# # sequana_coverage test case example (Bacteria Staphylococcus aureus)
#
# This notebook illustrates the impact of the window parameter on
# the results.
#
# Here, we can download a BED file generated for you:
#
# ```
# wget https://github.com/sequana/resources/raw/master/coverage/FN433596.bed.bz2
# bunzip2 FN433596.bed
# ```
#
# If you want to reproduce this BED file, please see the **bacteria** notebook
#
# Versions used:
# - sequana 0.6.4
# - bwa mem 0.7.15
# - bedtools 2.26.0
# - samtools 1.5
# - synapseclient 1.7.2

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = [10,7]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Sequana coverage (library)
#
# Here we will execute the coverage code to search for ROIs but looking at the impact of the window size parameter. Instead of using the standalone code we will the library to be able to loop through the window parameter.

# %%
from sequana import GenomeCov
import sequana
sequana.logger.level = "ERROR"
# load the BED and genbank file
b = GenomeCov("FN433596.bed", "FN433596.gbk")
b.compute_gc_content("FN433596.fasta")

# %%
# load the first chromosome and compute running median and get z-scores
chromosome = b.chr_list[0]
chromosome.thresholds.low = -4
chromosome.thresholds.high = 4
chromosome.run(20001, circular=True)
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="c47c052f-3e50-4b90-bf58-a45b2a89b22d" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="ab9b83a5-a42a-494a-937b-319e1f9f4855" style="padding-left: 10px;" text = ""/>

# %%
rois = chromosome.get_rois()
rois.df
# Out:
#                           chr    start      end  size    mean_cov  max_cov  \
# 0     ENA|FN433596|FN433596.1        1       24    23  327.869565      406
# 2     ENA|FN433596|FN433596.1     5371     5410    39  367.205128      406
# 3     ENA|FN433596|FN433596.1     5371     5410    39  367.205128      406
# 4     ENA|FN433596|FN433596.1     6190     6249    59  348.610169      406
# 6     ENA|FN433596|FN433596.1    10410    10442    32  348.437500      402
# 7     ENA|FN433596|FN433596.1    10410    10442    32  348.437500      402
# 8     ENA|FN433596|FN433596.1    10410    10442    32  348.437500      402
# 9     ENA|FN433596|FN433596.1    10410    10442    32  348.437500      402
# 10    ENA|FN433596|FN433596.1    10410    10442    32  348.437500      402
# 11    ENA|FN433596|FN433596.1    17277    17309    32  638.812500      652
# 13    ENA|FN433596|FN433596.1    20185    20188     3  404.000000      405
# 14    ENA|FN433596|FN433596.1    20185    20188     3  404.000000      405
# 15    ENA|FN433596|FN433596.1    20185    20188     3  404.000000      405
# 16    ENA|FN433596|FN433596.1    20185    20188     3  404.000000      405
# 17    ENA|FN433596|FN433596.1    20185    20188     3  404.000000      405
# 19    ENA|FN433596|FN433596.1    22003    22006     3  403.000000      404
# 20    ENA|FN433596|FN433596.1    22003    22006     3  403.000000      404
# 21    ENA|FN433596|FN433596.1    22003    22006     3  403.000000      404
# 22    ENA|FN433596|FN433596.1    22003    22006     3  403.000000      404
# 23    ENA|FN433596|FN433596.1    22003    22006     3  403.000000      404
# 25    ENA|FN433596|FN433596.1    24149    24251   102  356.833333      400
# 27    ENA|FN433596|FN433596.1    24149    24251   102  356.833333      400
# 29    ENA|FN433596|FN433596.1    26042    26065    23  379.434783      404
# 30    ENA|FN433596|FN433596.1    26042    26065    23  379.434783      404
# 4106  518.000000    -3.095731   -3.223462   -0.369864    3024426  3025388
# 4107  518.000000    -3.095731   -3.223462   -0.369864    3024516  3025382
# 4109  519.000000    -4.109676   -5.080813   -0.515765    3025660  3026460
# 4110  519.000000    -4.109676   -5.080813   -0.515765    3025720  3026442
# 4112  517.000000     3.078594    3.199357    0.295266    3028312  3030192
# 4114  518.000000     3.193152    3.324640    0.305120    3031562  3032059
# 4116  519.000000    -4.023586   -4.765849   -0.502788    3032061  3032810
# 4117  524.000000    -3.388423   -4.018613   -0.410488        nan      nan
# 4118  521.923077    -4.275652   -5.531998   -0.541090    3042862  3042993
#
#               type     gene_name strand  \
# 0             None          None   None
# 2              CDS          gyrB      +
# 3     misc_feature          gyrB      +
# 4     misc_feature          gyrB      +
# 6              CDS  SATW20_00070      -
# 7     misc_feature  SATW20_00070      -
# 8     misc_feature  SATW20_00070      -
# 9     misc_feature  SATW20_00070      -
# 10    misc_feature  SATW20_00070      -
# 11            None          None   None
# 13             CDS  SATW20_00140      +
# 14     sig_peptide  SATW20_00140      +
# 15    misc_feature  SATW20_00140      +
# 16    misc_feature  SATW20_00140      +
# 17    misc_feature  SATW20_00140      +
# 19             CDS          dnaC      +
# 20    misc_feature          dnaC      +
# 21    misc_feature          dnaC      +
# 22    misc_feature          dnaC      +
# 23    misc_feature          dnaC      +
# 25            tRNA   SATW20_t010      +
# 27            tRNA   SATW20_t020      +
# 29             CDS          yycG      +
# 30    misc_feature          yycG      +
# 31    misc_feature          yycG      +
# 33             CDS          sasH      +
# 34     sig_peptide          sasH      +
# 36             CDS  SATW20_00250      +
# 37    misc_feature  SATW20_00250      +
# 38    misc_feature          None      +
# ...            ...           ...    ...
# 4079           CDS           lip      -
# 4080   sig_peptide           lip      -
# 4081  misc_feature           lip      -
# 4082  misc_feature           lip      -
# 4083  misc_feature           lip      -
# 4084  misc_feature           lip      -
# 4085          None          None   None
# 4087           CDS  SATW20_28210      -
# 4089           CDS  SATW20_28230      -
# 4090  misc_feature  SATW20_28230      -
# 4092           CDS           cna      -
# 4093          None          None   None
# 4095           CDS  SATW20_28300      +
# 4096  misc_feature  SATW20_28300      +
# 4097  misc_feature  SATW20_28300      +
# 4098  misc_feature  SATW20_28300      +
# 4099          None          None   None
# 4101           CDS  SATW20_28310      -
# 4102  misc_feature  SATW20_28310      -
# 4103  misc_feature  SATW20_28310      -
# 4105           CDS  SATW20_28330      +
# 4106  misc_feature  SATW20_28330      +
# 4107  misc_feature  SATW20_28330      +
# 4109           CDS  SATW20_28340      +
# 4110  misc_feature  SATW20_28340      +
# 4112           CDS          vraE      +
# 4114           CDS  SATW20_28390      -
# 4116           CDS  SATW20_28400      -
# 4117          None          None   None
# 4118  misc_feature          rpmH      -
#
#                                                 product
# 0                                                  None
# 2                                  DNA gyrase subunit B
# 3      HMMPfam hit to PF02518, HATPase_c, score 1.7e-28
# 4     HMMPfam hit to PF00204, DNA_gyraseB, score 1.1...
# 6                        conserved hypothetical protein
# 7     HMMPfam hit to PF01256, Carb_kinase, score 1.1...
# 8     PS01050 Uncharacterized protein family UPF0031...
# 9     PS01049 Uncharacterized protein family UPF0031...
# 10    1 probable transmembrane helix predicted for S...
# 11                                                 None
# 13                            putative membrane protein
# 14    Signal peptide predicted for SATW20_00140 by S...
# 15    2 probable transmembrane helices predicted for...
# 16           HMMPfam hit to PF01368, DHH, score 2.7e-44
# 17           HMMPfam hit to PF02272, DHHA1, score 3e-09
# 19                                   DnaB-like helicase
# 20            HMMPfam hit to PF00772, DnaB, score 2e-49
# 21       HMMPfam hit to PF03796, DnaB_C, score 1.5e-142
# 22       PS00017 ATP/GTP-binding site motif A (P-loop).
# 23    Predicted helix-turn-helix motif with score 11...
# 25                                             tRNA-Glu
# 27                                             tRNA-Asp
# 29              transcriptional regulatory protein WalK
# 30    2 probable transmembrane helices predicted for...
# 31     HMMPfam hit to PF02518, HATPase_c, score 6.1e-43
# 33               putative LPXTG surface 5'-nucleotidase
# 34    Signal peptide predicted for SATW20_00230 by S...
# 36                       conserved hypothetical protein
# 37       HMMPfam hit to PF02590, DUF163, score 8.2e-137
# 38                                           SCCmercury
# ...                                                 ...
# 4079                                   lipase precursor
# 4080  Signal peptide predicted for SATW20_28080 by S...
# 4081               PS00120 Lipases, serine active site.
# 4082     PS00017 ATP/GTP-binding site motif A (P-loop).
# 4083  1 probable transmembrane helix predicted for S...
# 4084  HMMPfam hit to PF04650, YSIRK_signal, score 1e-12
# 4085                                               None
# 4087                ABC transporter ATP-binding protein
# 4089                     conserved hypothetical protein
# 4090         HMMPfam hit to PF01887, DUF62, score 3e-73
# 4092                                   collagen adhesin
# 4093                                               None
# 4095            sodium:sulfate symporter family protein
# 4096  HMMPfam hit to PF00939, Na_sulph_symp, score 1...
# 4097  12 probable transmembrane helices predicted fo...
# 4098  PS00013 Prokaryotic membrane lipoprotein lipid...
# 4099                                               None
# 4101                          putative membrane protein
# 4102  10 probable transmembrane helices predicted fo...
# 4103        HMMPfam hit to PF00892, DUF6, score 8.4e-08
# 4105                  putative nickel transport protein
# 4106  8 probable transmembrane helices predicted for...
# 4107       HMMPfam hit to PF03824, NicO, score 1.7e-138
# 4109                       putative N-acetyltransferase
# 4110  HMMPfam hit to PF00797, Acetyltransf_2, score ...
# 4112                   ABC transporter permease protein
# 4114                               hypothetical protein
# 4116                          putative exported protein
# 4117                                               None
# 4118  HMMPfam hit to PF00468, Ribosomal_L34, score 3...
#
# [3075 rows x 16 columns]

# %%
# 5Mb data points. So, this may take a while.
chromosome.plot_coverage()

# %% [markdown]
# The following code is a function that does the analysis shown above, that is
# the running median, zscore computation, identification of the ROI, and some
# plotting. The function then returns the ROIs

# %%
def identify_rois_and_plot_variant( x1=526000, x2=538000, W=20001):
    clf()    
    from sequana import GenomeCov
    # load the BED and genbank file
    b = GenomeCov("FN433596.bed", "FN433596.gbk")
    b.chr_list[0]._df = b.chr_list[0].df.iloc[x1:x2]
    #b.compute_gc_content("FN433596.fasta")
    chromosome = b.chr_list[0]
    chromosome.run(W, circular=True)
    chromosome.plot_coverage()
        
    roi = chromosome.get_rois()
    low = roi.get_low_rois()
    high = roi.get_high_rois()
    
    chr = chromosome
    highT = (chr.thresholds.high * chr.best_gaussian["sigma"] +
         chr.best_gaussian["mu"]) * chr.df["rm"]
    lowT = (chr.thresholds.low * chr.best_gaussian["sigma"] +
        chr.best_gaussian["mu"]) * chr.df["rm"]

    if len(low):
        for k,v in low.iterrows():        
            Y1 = chr.df['cov'].loc[v.start:v.end]
            Y2 = lowT.loc[v.start:v.end] 
            Y1 = Y1.combine(Y2, max) *0
            if v.start > x1 and v.end<x2:
                try:fill_between(range(v.start, v.end+1), Y1, Y2, alpha=0.6, color="blue")
                except:pass
    
    if len(high):
        for k,v in high.iterrows():
            Y1 = highT.loc[v.start:v.end]
            Y2 = chr.df['cov'].loc[v.start:v.end]
            Y2 = Y2.combine(Y1,max)
            if v.start > x1 and v.end<x2:
                try:fill_between(range(v.start, v.end+1), y1=Y1,y2=Y2 ,alpha=0.6, color="orange")
                except:pass

    xlim([x1,x2])

    return roi

# %% [markdown]
# First, let us use a small window size of only 2000 bases.
# If we focus on the area where there is a deleted regions, we see that the thresholds (implied by the running median) are affected by the deleted
# regions. This means that even the running median did not ignore the deleted regions. To be ignored, the window parameter should be twice as much as the deleted regions itself

# %%
# Here we emphasize the fact that you will miss simple CNV-like event
# if the window parameter is too short. For instance this 1100-long 
# event is missed because the window itself is less than 2 times 1100
roi2000 = identify_rois_and_plot_variant(W=2001, x1=526000, x2=538000)
ylim([0,800])
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="786acc7e-73a6-45ec-bd4f-fc9488887b2b" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="ebb14aa1-0428-419c-9cf6-a626e8842fe5" style="padding-left: 10px;" text = ""/>
# (0, 800)

# %%
# To detect the 1100-long deleted regions, a window size of 2200 is enough. 
# even though, slightly larger (e.g. 2300) would give a smooth threshold/runing median 
# curves
# Moreover, as can be seen in this example, the event detected at position
# around 527,000 is still detected.
roi2200 = identify_rois_and_plot_variant(W=2200, x1=526000, x2=538000)
ylim([0,800])
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="7e5e58df-2702-4836-a904-36d31a401098" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="5b2efc71-4a16-4658-86a5-c0474c7cbeee" style="padding-left: 10px;" text = ""/>
# (0, 800)

# %% [markdown]
# We have ran sequana_coverage to store the ROIs for different window size.
# There is no gold standdard but we can compare the different results and show that
# the impact of the window parameter is small.

# %%
import pandas as pd

# %%
bins = range(0, 4000, 100)
rois1000 = pd.read_csv("rois_1000.csv")
rois2200 = pd.read_csv("rois_2200.csv")
rois4000 = pd.read_csv("rois_4000.csv")
rois32000 = pd.read_csv("rois_32000.csv")
rois64000 = pd.read_csv("rois_64000.csv")


_ = hist([rois1000['size'], rois2200['size'], rois4000['size'], rois32000['size'], rois64000['size']], bins=bins, log=True)
legend(["1000", "2200", "4000", "32000", "64000"])
# Out:
# /home/cokelaer/miniconda3/envs/py3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
_ = identify_rois_and_plot_variant(x1=2000000,x2=2500000, W=160001)
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="388d896a-dcbb-478d-b98d-37d820317980" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="826e3e80-82d3-4795-8ae2-6b00c9615d97" style="padding-left: 10px;" text = ""/>

# %% [markdown]
# Impact of using a larger window: You may not follow the trend closely anymore, which may be an isssue with
# coverage signal with lots of fluctuations. Conversely, With too small windows (here 1000 bases), you may more
# non important event being detected
#
# For instance, here below, we have a few green circles just next to the threshold line (red line), which are detected
# but would not with the larger window.

# %%
chromosome.run(128000, circular=True)
chromosome.plot_coverage(sample=False)
for i,this in enumerate([1000,128000]):
    marker = "oo" 
    color = "gb"
    ms=[12,6]
    df = pd.read_csv("rois_{}.csv".format(this))    
    for _, d in df.iterrows():
        plot([d['start'], d['end']], [d["mean_cov"], d["mean_cov"]], marker[i], color=color[i], 
            markersize=ms[i], alpha=0.6, lw=1)
xlim([540000,610000])    
ylim([00,1200])
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="05b39710-4ee6-4a3a-9eb2-5412e88bf9e4" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="1597239a-fe5c-4320-be5e-4837b1de9460" style="padding-left: 10px;" text = ""/>
# (0, 1200)

# %%
Same as above but here the running median window was set to 1000.

# %%
chromosome.run(1000, circular=True)
chromosome.plot_coverage(sample=False)
for i,this in enumerate([1000,128000]):
    marker = "oo" 
    color = "gb"
    ms=[12,6]
    df = pd.read_csv("rois_{}.csv".format(this))    
    for _, d in df.iterrows():
        plot([d['start'], d['end']], [d["mean_cov"], d["mean_cov"]], marker[i], color=color[i], 
            markersize=ms[i], alpha=0.6, lw=1)
xlim([540000,610000])    
ylim([0,1200])
# Out:
#             <div style="float: left; border: 1px solid black; width:500px">
#               <div id="1b90eeb7-e23a-42b8-897e-131b97f74cff" style="background-color:blue; width:0%">&nbsp;</div>
#             </div>
#             <label id="ba9ea545-30dc-415b-9393-2900b51ceb4e" style="padding-left: 10px;" text = ""/>
# (0, 1200)

# %% [markdown]
# Using the previous code, you can simply compare two sets of ROIs available in the directory

# %%
import glob
glob.glob("rois*csv")
# Out:
# ['rois_64000.csv',
#  'rois_1000.csv',
#  'rois_128000.csv',
#  'rois_256000.csv',
#  'rois_32000.csv',
#  'rois_2200.csv',
#  'rois_4000.csv',
#  'rois_16000.csv',
#  'rois_8000.csv']

# %% [markdown]
# # Criteria to select the window size of 20,000
#
# There seem to be false alarm increase for low window size.
# For instance, if we plot the number of ROIs for window size from 1000 to 256,000 as show below, there seem to be a plateau after 20,000 qhere the number of events converges to about 650.
#
# Choosing 20,000 (in this case) seems to be a good choice since it reducs the false alarm. Larger window, would be useful only to detect deleted or duplicated regions.
#
# drawbacks of large windows:
# - time computation may be a bit slower
# - you may miss fluctuations.

# %%
L = []
vals = [1000,2200,4000,8000,16000,20000,24000, 32000,48000, 64000,72000,
        104000, 128000,176000, 232000, 256000]
for this in vals:
    df = pd.read_csv("rois_{}.csv".format(this))
    L.append(len(df))
plot(vals, L, "o-")
ylim([600,800])
M = mean( [l for l,v in zip(L, vals) if v>20000])
print(M)
axhline(M, color="r", ls="--")
axvline(20000, color="r", ls="--")
# Out:
# 663.8
